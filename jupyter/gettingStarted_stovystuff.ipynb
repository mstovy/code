# %%
# gettingStarted_stovystuff.ji
# Stovy's First Julia Doc

using Printf
using Statistics

#I will have an application that has a menu and several operations
# menu opertates as an infitine loop until choice 5 is chosen then menuswitch is flipped
# which ends up closing the program
function mainMenu()
    menuString = "Welcome to Stovy's first Julia Program\n\nPlease select an Option:\n1. Change Figure-Outer\n2. Some Other Number thing\n3. Create HTML Documents\n4. Stylyze Docs\n5. Exit"
    menuErrorMSG = "\nPlease Enter a valid number (1-5)\n\n"
    menuSwitch = 1
    userChoice = 0
    while menuSwitch == 1
        println(menuString)
        userChoice = readline()
        if userChoice == "1"
            changeFigure()
        elseif userChoice == "2"
            numberThing()
        elseif userChoice == "3"
            createHTML()
        elseif userChoice == "4"
            stylyzeDocs()
        # FIXME EXIT FUNCTION
        elseif userChoice == "5"
            menutSwitch = 0
        else
            println(menuErrorMSG)
        end
    end
end

################################################

# similar to my last algorithm homeowork in python but implemented into Julia
function changeFigure()
    changeSwitch = 1
    changePrompt1 = "1.To enter Dollar Amount \n2.To Return to Main Menu"
    changeErrorMSG = "Please Enter a valid number (1-2)"
    changePrompt2 = "Please Enter a Dollar Amount: "
    while (changeSwitch == 1)
        println(changePrompt1)
        changeUserChoise = readline()
        if changeUserChoise == "1"
            println(changePrompt2)
            changeInput = readline()
            changeInputInt = parse(Float64, changeInput)
            changeArray = mCount(changeInputInt)
            Printf("\n", changeArray[10], "pennies\n", changeArray[9], "nickles\n", changeArray[8], "dimes\n", changeArray[7], "quarters\n", changeArray[6], "1 Dollar Bills\n", changeArray[5], "5 Dollar Bills\n", changeArray[4], "10 Dollar Bills\n", changeArray[3], "20 Dollar Bills\n", changeArray[2], "50 Dollar Bills\n", changeArray[1], "100 Dollar Bills\n")
        elseif changeUserChoise == "2"
            changeSwitch = 0
        else
            println(changeErrorMSG)
        end
    end
end
function mDiv(amount, money)
    count = floor(amount / money)
    remainder = round(amount % money)
    return remainder, count
end
function mCount(amount)
    indexB = 1
    billArray = fill(0.0, (10))
    intArray = (100, 50, 20, 10, 5, 1, 0.25, 0.10, 0.05, 0.01)
    while amount != 0
        amount, returnNum = mDiv(amount, intArray[indexB])
        billArray[indexB] = returnNum
        if indexB > 9
            return billArray
        end
    end
    return billArray
end

################################################
        
        
# figure out what you wanna do with this function dude
function numberThing()
end
        
################################################
        

# create an HTML doc with a chanrt or table or somthing
function createHTML()
end
        
################################################
        
        
# get good at stylyzing your HTML docs and do some of that in here
function stylyzeDocs()
end

mainMenu()
# Out:
# Welcome to Stovy's first Julia Program
#
# Please select an Option:
# 1. Change Figure-Outer
# 2. Some Other Number thing
# 3. Create HTML Documents
# 4. Stylyze Docs
# 5. Exit
# stdin> 1
# 1.To enter Dollar Amount
# 2.To Return to Main Menu
# stdin> 1
# Please Enter a Dollar Amount:
# stdin> 10.99
